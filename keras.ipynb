# %% [markdown]
# <a href="https://colab.research.google.com/github/mannyrz/CharterTvSim/blob/master/keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import model_from_json

from matplotlib import pyplot as plt

import numpy as np

# %%
def function(x):
    return 10*x**2 - 5*x - 0.5

# %%
x_train = np.random.rand(1000)
y_train = function(x_train)

x_test =  np.linspace(0, 1, 100)
y_test = function(x_test)

# %%
plt.scatter(x_train, y_train, label='Train', color='blue')
plt.plot(x_test, y_test, label='Test', color='red')
plt.ylabel('y')
plt.xlabel('x')
plt.legend(loc='best')
plt.show()

# %%
model = Sequential()
model.add(Dense(units=200, input_dim=1))
model.add(Activation('relu'))
model.add(Dense(units=20))
model.add(Activation('relu'))
model.add(Dense(units=1))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='mean_squared_error', optimizer=Adam())
history = model.fit(x_train, y_train, batch_size=50, epochs=10, verbose=1, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.5516 - val_loss: 2.3431
# Epoch 2/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2831 - val_loss: 2.0020
# Epoch 3/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8657 - val_loss: 1.6535
# Epoch 4/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5445 - val_loss: 1.2754
# Epoch 5/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1501 - val_loss: 0.8814
# Epoch 6/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7759 - val_loss: 0.5270
# Epoch 7/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4308 - val_loss: 0.2724
# Epoch 8/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2208 - val_loss: 0.1486
# Epoch 9/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1239 - val_loss: 0.0954
# Epoch 10/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0796 - val_loss: 0.0677

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
y_predictions = model.predict(x_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
plt.scatter(x_test, y_predictions, label='Predictions', color='blue')
plt.plot(x_test, y_test, label='Test', color='red')
plt.ylabel('y')
plt.xlabel('x')
plt.legend(loc='best')
plt.show()
